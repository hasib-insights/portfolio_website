# %% [markdown]
# <a href="https://colab.research.google.com/github/hasib-insights/portfolio_website/blob/main/Numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
print("NUMPY version:", np.__version__)
# Out:
# NUMPY version: 2.0.2
